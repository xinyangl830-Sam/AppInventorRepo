# %% [markdown]
# <a href="https://colab.research.google.com/github/xinyangl830-Sam/AppInventorRepo/blob/main/%E5%AD%B8%E7%BF%92typingclub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 點選上方的 **Open in Colab**，
# *   再點選上面的 "**複製到雲端硬碟**"
# *   注意注意注意，一定要點選上面的 "**複製到雲端硬碟**"，才能複製到雲端硬碟的 **Colab**
#
# 按完**複製到雲端硬碟**，請**刪除**此文字區塊，正式在以下開始  **學習 Colab**

# %% [markdown]
# # **學習 Colab 環境**

# %% [markdown]
# 修改最上面"修改此檔名.ipynb" 檔名: **學習typingclub.ipynb**

# %% [markdown]
# 嘗試，使用下面圖案的紅框
#
# *   新增程式碼，新增文字
# *   刪除程式碼，刪除文字

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **新增文字**
#
# 1.   新增文字
# 2.   輸入"我是南大附中高二學生，???，這是我輸入的文字"
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **新增程式碼**
#
# 1.   print("Hello World")
# 2.   執行
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **刪除下面的文字區塊**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 主人，不要手下留情，請務必**刪除**我，**哭哭，馬上不見**

# %% [markdown]
# **先持行下面程式碼，再刪除下面的程式碼區塊**
# ![image.png](data:image/png;base64,...)

# %%
# 請主人，展示刪除此程式碼區塊的魔法
print("主人將施展魔法，我是即將消失的程式碼")

# %% [markdown]
# # **學習 TypingClub 環境**

# %% [markdown]
# Google: **TypingClub** [連結文字](https://www.typingclub.com/)

# %% [markdown]
# ##註冊

# %% [markdown]
# *   新註冊
# *   以 google 帳號，註冊登入

# %% [markdown]
# ##第一關的影片 [連結文字](https://www.edclub.com/sportal/program-3/116.play)

# %% [markdown]
# 看完後，**請說明影片重點**
# 1.   重點1
# 2.   重點2

# %% [markdown]
# ##英打的想法

# %% [markdown]
# 1.   「慢慢打」：追求「絲滑感」，而非爆發力
# 2.   「忙中有錯」：寧可慢，也不要錯
# 3.   「不要低頭」：封印視覺，啟動觸覺
# 4.   「不要怕錯誤」：錯誤是為了校準大腦，錯越多，越厲害
#
# 給你們講一個台大畢業的漂亮長髮姊姊，她發生的真實故事。

# %% [markdown]
# 從前我應徵上某單位，剛進去工作時，發現，有一個
# ....
#
# 另一個也是台大畢業的短髮姊姊，已經結婚.....

# %% [markdown]
# # **紀錄 TypingClub 學習成果**

# %% [markdown]
# 對高中生「學程式」的關鍵關卡，建議如果你是為了寫程式，請特別留意以下幾段關卡：
#
# 第 317 - 346 關（Symbols）： 練習 $, &, #, *, @, ( ), !, %, ^。這些在變數宣告和邏輯判斷中極常用。
#
# 第 404 - **418** 關（More Symbols）： 這區最重要！ 練習 { }, \, |, <, >。這是寫 C++、Java 或 Python 縮排與語法結構的命脈。

# %% [markdown]
# 請學會 **Ctrl + win + s**，擷取畫面如下

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 我的成績擷取畫面如下

# %% [markdown]
# Ctrl + V 張貼於此
#
#
# ---
# ![image.png](data:image/png;base64,...)

# %%
#我的計算成績方式
import math

total_level = 418
my_level = 146 # 假設打到第 146 關

# 使用 round(數字, 小數點位數)
score = round(math.sqrt(my_level / total_level) * 100, 2)

print("我的進度分數是：", score)
# Out:
# 我的進度分數是： 59.1

# %% [markdown]
# ## **我的進度分數是： 59.1**

# %% [markdown]
# #**學習在 GitHub， new 一個 repository: "TypingClub"**

# %% [markdown]
# ## 註冊

# %% [markdown]
# *   新註冊
# *   或 以google帳號，註冊登入

# %% [markdown]
# ## new repository

# %% [markdown]
# ###如下圖**紅框**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### new repository 如下圖，輸入: **TypingClub**，注意: **Public**， 然後**Python**，最後，**Create repository**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Colab儲存 學習typingclub.ipynb，再"在GitHub中儲存副本"**

# %% [markdown]
# ##1. 在Colab中，儲存 **Ctrl + s**，下面左邊，出現"儲存成功"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##2. 在Colab中，上面 "**檔案**" ，再到 "**在GitHub中儲存副本**"，如下圖紅框

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##3. 在GitHub中儲存副本後，選擇 GitHub repository: **TypingClub**，注意下圖**紅框**的部分

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###

# %% [markdown]
# #**公開分享你github的repository: TypingClub，方便審查學習過程**

# %% [markdown]
# 詢問 AI，如何公布GitHub的repository
#
# *   建議使用 **google gemini**
# *   詢問如何公布GitHub 含此記事本的repository: **TypingClub**，類似 https:// github.com /你的github帳號 /TypingClub.git

# %% [markdown]
# # **在Google 的 ClassRoom 繳交學習報告 清明節04/05 23:59前**

# %% [markdown]
# 用AI ，建議 Gemini，製作一頁成果簡報，內如如下，導出的 pdf 或 JPG，清明節04/05 23:59前，上傳 此 pdf 或 JPG，也上傳到 你github的repository: **TypingClub**，方便審查學習過程
#
#
# 1.   學號班級姓名
# 2.   計算後的成績(四捨五入)英打的
# 3.   證明英打關卡的圖案
# 4.   typintclub，簡要學習心得100字以內
# 5.   提供給老師檢查 github的網址 類似 https:// github.com /你的github帳號 /TypingClub.git
# 6.   此網址的QR code
#
# 參考如下兩圖

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **請檢查你的作業，本次作業清明節4月5日截止**
