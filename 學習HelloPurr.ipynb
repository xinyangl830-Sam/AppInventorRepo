# %% [markdown]
# <a href="https://colab.research.google.com/github/xinyangl830-Sam/AppInventorRepo/blob/main/%E5%AD%B8%E7%BF%92HelloPurr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **複製 學生HelloPurr.ipynb 到 你的Colab**
# 點選上方的 Open in Colab，
#
# *   再點選  "複製到雲端硬碟"
# *   注意注意注意，一定要點選上面的 "複製到雲端硬碟"，才能複製到雲端硬碟的 **Colab**
# *   點按完，請刪除此文字區塊，正式在以下正式開始
# *   **學生**HelloPurr.ipynb 改為 **學習**HelloPurr.ipynb
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **建立你的第一個應用：HelloPurr** [連結文字](https://appinventor.mit.edu/explore/ai2/hellopurr)

# %% [markdown]
# **HelloPurr：輕拍小貓，聽它喵喵叫** [連結文字](https://appinventor.mit.edu/explore/ai2/hellopurr)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 您需要一張**貓的圖片檔案** 和一個 **「喵」的音訊檔案**。**右鍵單擊**以下鏈接，選擇“鏈接另存為…”即可將這些文件下載到您的電腦。將這兩個檔案儲存到桌面、下載資料夾或其他方便您日後查找的位置。
#
# **小貓圖片**：kitty.png（右鍵並儲存）[連結文字](https://appinventor.mit.edu/explore/sites/all/files/ai2tutorials/helloPurr/kitty.png)
#
# **喵喵聲**：meow.mp3（右鍵另存為）[連結文字](https://appinventor.mit.edu/explore/sites/all/files/ai2tutorials/helloPurr/meow.mp3)

# %% [markdown]
# 下載 一張**貓的圖片檔案** 和一個 **「喵」的音訊檔案**。
#
# **請回答是否完成?**
#
# ---

# %% [markdown]
# # **建立Apps， Create Apps**

# %% [markdown]
# 1.   登入 google gmail
# 2.   google: app inventor 找到 https://appinventor.mit.edu/
# 3.   創造 Apps，點選 **Create Apps!**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 建立新專案 **New project**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Project name: **HelloPurr**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **手機型號**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Project name: HelloPurr
#
# **請回答是否完成?**
#
# ---

# %% [markdown]
# # **設計外觀 Disigner** 選擇組件來設計您的應用程式

# %% [markdown]
# **App Inventor 元件**
#
# 左側的「面板」。元件組件是您在手機或平板電腦上創建應用程式的基本元素，就像食譜中的食材一樣。有些元件非常簡單，例如**標籤**元件（紅框第2個），它只會在螢幕上顯示文字；或**按鈕**元件（紅框
#
# ```
# # 此內容會顯示為程式碼
# ```
#
# 第1個），點擊即可觸發操作。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 要在應用程式中使用元件，將其拖放到設計器中間的檢視器中

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 元件新增至檢視器後，它也會出現在檢視器右側的元件清單中，元件（見下圖左紅框）。
#
# 若要檢視和變更元件的屬性（見下圖右紅框），先在元件清單中，選擇所需的元件。調整屬性，可改變元件在應用程式中的外觀或行為。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **選擇組件和設定屬性的步驟**

# %% [markdown]
# **步驟 1.** 要先確認已經下載的小貓圖片檔案與聲音檔案。
#
# 步驟 1a . 從使用者介面面板中，將Button按鈕元件拖曳到 Screen1上，創建**Button1**。
#
# 步驟 1b . **Button1**“屬性”(第一個紅圈)，窗格下的**Image 圖像**，單擊**None... 無...**（如下左圖），然後單擊 **Upload file 上傳新圖像** （如下右圖）。
#
#
# 步驟 1c . 此時會彈出一個窗口，讓您選擇圖像檔案。點擊“選擇檔案”，然後找到您之前下載的kitty.png檔案所在位置（#3）。按一下kitty.png文件，按一下“開啟”，然後按一下“確定”。

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **步驟 2.** 更改按鈕的Text屬性：刪除“button1 按鈕1”的文字，將按鈕的Text屬性留空，這樣小貓的臉上就不會有任何文字。
#
# 將 Test的文字(**Text for Button1**)清除，貓鼻子上的文字Text for Button1，就會消失

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 小貓圖片沒有完全顯示Screen1的螢幕寬度，將Button1 按鈕1的「寬度」屬性設為「填滿父元素」來解決此問題如下左圖。
#
# 右圖是結果。寬胖展現它的可愛。

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **步驟 3.** 從使用者介面面板中，將Label標籤組件，拖曳到Screen1中，並將其放置在小貓圖片下方。它將在組件清單中顯示為“Label**1**”。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 在「屬性」窗格中，將**Label1**的屬性變更
#
# *   背景顏色：藍色
# *   字體大小：30
# *   Text：Pet the Kitty!
# *   文字顏色：黃色

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **步驟 4.** 點選 Media「媒體」抽屜，拖曳一個 Sound「聲音」元件，並將拖曳在Screen1中)。無論放置在何處，它都會出現在底部標記為「不可見組件」的區域中。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 在右側中間Media「媒體」窗格中，按 **Upload File「上傳新內容...」**。瀏覽到您先前下載的meow.mp3檔案所在的位置，並將其上傳)。
#
# 在「屬性」窗格中，可以看到 **Source「來源」**屬性目前顯示為 **None...「無...」**。按 **None...「無...」**，將 Sound1 元件的「來源」變更為meow.mp3，按 **OK**。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 設計外觀 Disigner 選擇組件來設計您的應用程式
#
# **請回答是否完成?**
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **請回答是否完成?**
#
#
# ---

# %% [markdown]
# # **程式設計 Blocks** 使用積木編輯器Blocks，進行編程

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **播放聲音**

# %% [markdown]
# **步驟 1.** 在模組編輯器的左側，選 Button1「按鈕 1」抽屜，將其開啟。將 Button1 Click模組，**拖曳**到工作區（右側的空白區域）中。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **步驟 2.** 點選Sound1抽屜，拖曳Sound1.Play模組並將其連接到「當 Button1.Click」模組的「執行」部分。這些模組像拼圖一樣連接在一起，連接時會發出咔噠聲。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **挑戰！讓貓咪發出振動**

# %% [markdown]
# 挑戰！讓貓咪發出呼嚕聲
# 挑戰在於按下按鈕時讓貓咪發出呼嚕聲。前往程式碼區塊編輯器，打開 Sound**1** “聲音1”抽屜，拖曳 Sound**1** “聲音1.振動”程式碼區塊並將其放置在“聲音1.播放”程式碼區塊下方。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 使用積木編輯器Blocks，進行程式設計 編程
#
# **請回答是否完成?**
#
# ---

# %% [markdown]
# **手機測試第一階段**
#
# *   手機新增 App
# *   android 手機https://play.google.com/store/apps/details?id=edu.mit.appinventor.aicompanion3&hl=zh_HK
# *   iPhone 手機https://apps.apple.com/tw/app/mit-app-inventor/id1422709355

# %% [markdown]
# ![unnamed.png](data:image/png;base64,...)

# %% [markdown]
# **手機測試第二階段**
#
# *   點選手機上圖的App，開啟 App
# *   點選 **scan QR code**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **手機測試第三階段**
#
# *   點選 專案上的 Connect 連線，開啟 App
# *   以手機 App scan QR code

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **完成 App inventor 學習心得**

# %% [markdown]
# **請簡單回答學習心得**
#
# 1.   心得項目
# 2.   心得項目
# 3.   心得項目
#
# ......
#
# ---

# %% [markdown]
# # **自學 github** ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **New** 新增一個 **repository**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####Repository name: **AppInventorRepo**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 檢查是否有 **AppInventorRepo**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **在 github 儲存副本**
# 此colab作業，儲存副本: **學生HelloPurr.ipynb**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.   在Colab儲存: **Ctrl + S**
# 2.   檔案 -> 在GitHub中儲存副本

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  在GitHub中儲存副本: **學生HelloPurr.ipynb**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **公開分享 你github的repository: "AppInventorRepo"**

# %% [markdown]
# ### 檢查 github 的AppInventorRepo 是否有: **學生HelloPurr.ipyn**b
#
# > 加入區塊引述符號

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Copy URL to clipboard

# %% [markdown]
# 如下圖，可以得到 https://github.com/你的帳號/AppInventorRepo.git
#
# 此 URL 是 透過 github **公開**，你的colab的內容

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 公開 **QR** code

# %% [markdown]
# google QR code
#
# https://quickmark.com.tw/cht/qrcode-datamatrix-generator/default.asp?qrLink

# %% [markdown]
# 請同學互相以手機，檢驗是否可以進入你的
#
# https://github.com/**你的帳號**/AppInventorRepo.git
